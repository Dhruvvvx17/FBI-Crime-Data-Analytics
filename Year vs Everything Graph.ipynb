# %%
import numpy as np
import matplotlib.pyplot as plt
#print("")

import pandas
years= pandas.read_csv('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\\CrimeStatebyState19602014.csv', index_col=0)
years.plot()
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import matplotlib.pyplot as plt
#print("Hello")

import pandas
years= pandas.read_csv('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\\CrimeStatebyState19602014.csv', index_col=3)
years.plot()

print("Hello")

# %%
import numpy as np
import matplotlib.pyplot as plt
#print("Hello")

import pandas
years= pandas.read_csv('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\\CrimeStatebyState19602014.csv', index_col=3)
years.plot()

print("Hello")
# Out:
# Hello

# %%
import numpy as np
import matplotlib.pyplot as plt
print("Graph for Year vs Everything")

import pandas
years= pandas.read_csv('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\\CrimeStatebyState19602014.csv', index_col=0)
# %matplotlib inline 
plt.rcParams['figure.figsize']=(20,10)
years.plot()
#print("Hello")
# Out:
# Graph for Year vs Everything
