# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df=pd.read_csv("C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv")
print("Hello")

data = np.genfromtxt('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv', delimiter=',', names=['x', 'y'])
plt.plot(data['Burglary'], data['Robbery'])
plt.show()
fig = plt.figure()
ax = plt.axes()

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));
# Out:
# Hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-ce4f2ac8da6a> in <module>()
#       8 print("Hello")
#       9
# ---> 10 data = np.genfromtxt('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv', delimiter=',', names=['x', 'y'])
#      11 plt.plot(data['Burglary'], data['Robbery'])
#      12 plt.show()
#
# C:\Anaconda\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2017             # Raise an exception ?
#    2018             if invalid_raise:
# -> 2019                 raise ValueError(errmsg)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df=pd.read_csv("C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv")
print("Hello")

from numpy import genfromtxt
per_data=np.genfromtxt(df)
#per_data=genfromtxt("C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv",delimiter=',')
plt.plot(per_data)
# Out:
# Hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-085819818ca2> in <module>()
#       7
#       8 from numpy import genfromtxt
# ----> 9 per_data=np.genfromtxt(df)
#      10 #per_data=genfromtxt("C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv",delimiter=',')
#      11 plt.plot(per_data)
#
# C:\Anaconda\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2017             # Raise an exception ?
#    2018             if invalid_raise:
# -> 2019                 raise ValueError(errmsg)
#    2020             # Issue a warning ?
# ...

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np

data = np.genfromtxt('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv', delimiter=',', names=['x', 'y'])

x=[]
y=[]

with open('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv', 'r') as csvfile:
    plots= csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))


plt.plot(x,y, marker='o')

plt.title('Data from the CSV File: People and Expenses')

plt.xlabel('Number of People')
plt.ylabel('Expenses')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-7f626893c0ed> in <module>()
#       3 import numpy as np
#       4
# ----> 5 data = np.genfromtxt('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv', delimiter=',', names=['x', 'y'])
#       6
#       7 x=[]
#
# C:\Anaconda\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2017             # Raise an exception ?
#    2018             if invalid_raise:
# -> 2019                 raise ValueError(errmsg)
#    2020             # Issue a warning ?
#    2021             else:
#
# ...

# %%
import pandas

data = pandas.read_csv('C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv', index_col='Year')

#population = data.loc['Popultion']
#robbery = data.loc['Robbery']

#plt.plot(population, robbery, 'b-', label='Australia')
#plt.plot(years, gdp_nz, 'g-', label='New Zealand')

years = data.columns.str.strip('Years')
data.columns = years.astype(int)




data.loc['2000'].plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in astype(self, dtype, copy)
#    1277         try:
# -> 1278             return Index(self.values.astype(dtype, copy=copy), name=self.name,
#    1279                          dtype=dtype)
#
# ValueError: invalid literal for int() with base 10: 'Population'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-bfd8bbcb797c> in <module>()
#      10
#      11 years = data.columns.str.strip('Years')
# ---> 12 data.columns = years.astype(int)
#      13
#      14
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in astype(self, dtype, copy)
#    1280         except (TypeError, ValueError):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df=pd.read_csv("C:\\Users\\Dev Bhartra\\Desktop\\Sem 3\\NOTES\\IDS\\CIUS 2017 Preliminary Excel Tables\CrimeStatebyState19602014.csv",index_col=1)

plot=population.plot(title='
df.plot()
plt.show()
